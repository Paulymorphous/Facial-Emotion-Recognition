# %% [markdown]
# # Facial Emotion Recognition
#
# A baby is able to recognize it's parent's faces when it is about a couple of weeks old. The baby grows and matures and by the time it is about two months old, it starts to display social cues. It is able to understand basic emotions like a smile.
#
# This project involves training a neural network to do just that, recognize facial emotions. We owe our ability to do that to the wonderful process of evolution. Replicating this is certainly not easy but possible.
#
# For this project, I will be using [Google Collab](/https://colab.research.google.com/). For those who are unaware, it is a research project created to disseminate ML education and you can train your neural networks on their Tesla K80 GPUs. It sure speeds up the entire training process.

# %% [markdown]
# ## 1.  Connect google Drive.
#
# Once connected, we will be able to access the FER2013 dataset.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ## 2. Import Libraries.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras.models import Sequential #Initialise our neural network model as a sequential network
from keras.layers import Conv2D #Convolution operation
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.layers import Activation#Applies activation function
from keras.layers import Dropout#Prevents overfitting by randomly converting few outputs to zero
from keras.layers import MaxPooling2D # Maxpooling function
from keras.layers import Flatten # Converting 2D arrays into a 1D linear vector
from keras.layers import Dense # Regular fully connected neural network
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, TensorBoard, ModelCheckpoint
from sklearn.metrics import accuracy_score
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 3. Define Data loading mechanism.
#
#
# the* load_data()* access the [FER2013](https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge/data) dataset from Google Drive and then we start reading it line by line. Our dataset has 35,887 images, which are classified into seven categories -  Angry, Disgust, Fear, Happy, Sad, Surprsie, and Neutral. Let us have a look at the file.
#
# ![Dataset overview](Assets\TrainingData.png)
#
# We are only going to need the Class and the Image Data. Image data is one big string of numbers exactly 2304 numbers. These are pixel intensity values and each number represents the darkness of that pixel in the image. It can take any value from 0 (White) to 255 (Black). We split the string to get hold of individual numbers and then reshape it into a 48 x 48 array and dividing by 255 normalizes the data.
#
# Once we go through all the images, we expand the dimension of our data array by one to accommodate for the channel value. We one-hot encode the labels then return the numpy arrays.

# %%
def load_data(dataset_path):

  data = []
  labels =[]

  with open(dataset_path, 'r') as file:
      for line_no, line in enumerate(file.readlines()):
          if 0 < line_no <= 35887:
            curr_class, line, set_type = line.split(',')
            image_data = np.asarray([int(x) for x in line.split()]).reshape(48, 48)#Creating a list out of the string then converting it into a 2-Dimensional numpy array.
            image_data =image_data.astype(np.uint8)/255.0
            data.append(image_data)
            labels.append(curr_class)
      data = np.expand_dims(data, -1)   
      labels = to_categorical(labels, num_classes = 7)
    
      return np.array(data), np.array(labels)

# %% [markdown]
# ## 4. Load the data.

# %%
seed = 7
test_size = 0.1
dataset_path = "/content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Data/fer2013.csv" 
data, labels = load_data(dataset_path)
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size = test_size,random_state = seed)

print("Number of images in Training set:", len(train_data))
print("Number of images in Test set:", len(test_data))
# Out:
# Number of images in Training set: 32298
# Number of images in Test set: 3589

# %% [markdown]
# ## 5. Define and Deploy the neural network.
#
# We have built ourselves a Convolutional Neural Network which has convolutional layers armed with filters that extract features out of images.
#
# Callback functions are those functions which are called at the end of every epoch and in this model, we use two callback functions - ReduceLROnPlateau and EarlyStopping.
#
#
#
# > **1. ReduceLROnPlateau:** monitors a certain variable, in this case, validation loss and alters the learning rate when the value stops significantly changing after some certain number of epochs (patience).
#
# >  **2. EarlyStopping:** At times our optimiser can land in *local optima* and get stuck there. There is no point in continuing the training as there won't be any further improvements.
#
# > **3. ModelCheckpoin**t: Saves the best version of our model along with the weights, so that in case any crash occurs, our model can be recovered.
#
# ![Network Architecture](Assets\NetworkArchitecture.png)
#
# We have used Keras to deploy our neural network and if you look at the architecture then you will notice that we have used Dropout layers frequently. Dropout layers inhibit overfitting by randomly dropping out units from the neural network. We will use 20 percent of the training data as validation data.

# %%
#######HYPERPARAMATERS###########
epochs = 100
batch_size = 64
learning_rate = 0.001
#################################

model = Sequential()
    
model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1), kernel_regularizer=l2(0.01)))
model.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(48, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
adam = optimizers.Adam(lr = learning_rate)
model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
print(model.summary())

lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3)
early_stopper = EarlyStopping(monitor='val_acc', min_delta=0, patience=6, mode='auto')
checkpointer = ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/Train_weights.hd5', monitor='val_loss', verbose=1, save_best_only=True)

model.fit(
          train_data,
          train_labels,
          epochs = epochs,
          batch_size = batch_size,
          validation_split = 0.2,
          shuffle = True,
          callbacks=[lr_reducer, checkpointer, early_stopper]
          )
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 48)                6192
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 48)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 343
# =================================================================
# Total params: 8,356,679
# Trainable params: 8,351,175
# Non-trainable params: 5,504
# _________________________________________________________________
# None
# Train on 25838 samples, validate on 6460 samples
# Epoch 1/100
# 25838/25838 [==============================] - 82s 3ms/step - loss: 2.0723 - acc: 0.2097 - val_loss: 1.8505 - val_acc: 0.2503
#
# Epoch 00001: val_loss improved from inf to 1.85046, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 2/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.8424 - acc: 0.2487 - val_loss: 1.8274 - val_acc: 0.2503
#
# Epoch 00002: val_loss improved from 1.85046 to 1.82738, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 3/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.8280 - acc: 0.2528 - val_loss: 1.8207 - val_acc: 0.2503
#
# Epoch 00003: val_loss improved from 1.82738 to 1.82068, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 4/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.8219 - acc: 0.2523 - val_loss: 1.8159 - val_acc: 0.2503
#
# Epoch 00004: val_loss improved from 1.82068 to 1.81590, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 5/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.8195 - acc: 0.2535 - val_loss: 1.8191 - val_acc: 0.2503
#
# Epoch 00005: val_loss did not improve from 1.81590
# Epoch 6/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.8154 - acc: 0.2531 - val_loss: 1.8178 - val_acc: 0.2503
#
# Epoch 00006: val_loss did not improve from 1.81590
# Epoch 7/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.8113 - acc: 0.2546 - val_loss: 1.8082 - val_acc: 0.2514
#
# Epoch 00007: val_loss improved from 1.81590 to 1.80822, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 8/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.8078 - acc: 0.2543 - val_loss: 1.8074 - val_acc: 0.2503
#
# Epoch 00008: val_loss improved from 1.80822 to 1.80737, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 9/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.8030 - acc: 0.2539 - val_loss: 1.8091 - val_acc: 0.2508
#
# Epoch 00009: val_loss did not improve from 1.80737
# Epoch 10/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.8047 - acc: 0.2526 - val_loss: 1.8096 - val_acc: 0.2503
#
# Epoch 00010: val_loss did not improve from 1.80737
# Epoch 11/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.7976 - acc: 0.2557 - val_loss: 1.7912 - val_acc: 0.2539
#
# Epoch 00011: val_loss improved from 1.80737 to 1.79117, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 12/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.7973 - acc: 0.2508 - val_loss: 1.7766 - val_acc: 0.2433
#
# Epoch 00012: val_loss improved from 1.79117 to 1.77662, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 13/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.7812 - acc: 0.2554 - val_loss: 1.8078 - val_acc: 0.2568
#
# Epoch 00013: val_loss did not improve from 1.77662
# Epoch 14/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.7810 - acc: 0.2648 - val_loss: 1.7687 - val_acc: 0.2605
#
# Epoch 00014: val_loss improved from 1.77662 to 1.76872, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 15/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.7705 - acc: 0.2626 - val_loss: 1.7377 - val_acc: 0.2543
#
# Epoch 00015: val_loss improved from 1.76872 to 1.73774, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 16/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.7184 - acc: 0.2949 - val_loss: 1.7788 - val_acc: 0.2579
#
# Epoch 00016: val_loss did not improve from 1.73774
# Epoch 17/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.6724 - acc: 0.3306 - val_loss: 1.6415 - val_acc: 0.3367
#
# Epoch 00017: val_loss improved from 1.73774 to 1.64153, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 18/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.6249 - acc: 0.3539 - val_loss: 1.6362 - val_acc: 0.3384
#
# Epoch 00018: val_loss improved from 1.64153 to 1.63622, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 19/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.5816 - acc: 0.3691 - val_loss: 1.5836 - val_acc: 0.3590
#
# Epoch 00019: val_loss improved from 1.63622 to 1.58361, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 20/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.5390 - acc: 0.3887 - val_loss: 1.4676 - val_acc: 0.4135
#
# Epoch 00020: val_loss improved from 1.58361 to 1.46756, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 21/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.5146 - acc: 0.3948 - val_loss: 1.4198 - val_acc: 0.4138
#
# Epoch 00021: val_loss improved from 1.46756 to 1.41975, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 22/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.4862 - acc: 0.4093 - val_loss: 1.4696 - val_acc: 0.4142
#
# Epoch 00022: val_loss did not improve from 1.41975
# Epoch 23/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.4731 - acc: 0.4114 - val_loss: 1.4467 - val_acc: 0.4243
#
# Epoch 00023: val_loss did not improve from 1.41975
# Epoch 24/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.4447 - acc: 0.4289 - val_loss: 1.4722 - val_acc: 0.4102
#
# Epoch 00024: val_loss did not improve from 1.41975
# Epoch 25/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.4274 - acc: 0.4278 - val_loss: 1.3688 - val_acc: 0.4412
#
# Epoch 00025: val_loss improved from 1.41975 to 1.36882, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 26/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.4063 - acc: 0.4309 - val_loss: 1.5067 - val_acc: 0.3986
#
# Epoch 00026: val_loss did not improve from 1.36882
# Epoch 27/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.3898 - acc: 0.4372 - val_loss: 1.3551 - val_acc: 0.4512
#
# Epoch 00027: val_loss improved from 1.36882 to 1.35507, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 28/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.3742 - acc: 0.4431 - val_loss: 1.3741 - val_acc: 0.4438
#
# Epoch 00028: val_loss did not improve from 1.35507
# Epoch 29/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.3599 - acc: 0.4517 - val_loss: 1.3825 - val_acc: 0.4362
#
# Epoch 00029: val_loss did not improve from 1.35507
# Epoch 30/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.3362 - acc: 0.4616 - val_loss: 1.3968 - val_acc: 0.4596
#
# Epoch 00030: val_loss did not improve from 1.35507
# Epoch 31/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.3132 - acc: 0.4858 - val_loss: 1.2887 - val_acc: 0.5098
#
# Epoch 00031: val_loss improved from 1.35507 to 1.28872, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 32/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.2855 - acc: 0.4989 - val_loss: 1.2869 - val_acc: 0.5118
#
# Epoch 00032: val_loss improved from 1.28872 to 1.28687, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 33/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.2560 - acc: 0.5100 - val_loss: 1.3033 - val_acc: 0.5084
#
# Epoch 00033: val_loss did not improve from 1.28687
# Epoch 34/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.2337 - acc: 0.5226 - val_loss: 1.2422 - val_acc: 0.5271
#
# Epoch 00034: val_loss improved from 1.28687 to 1.24218, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 35/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.2134 - acc: 0.5290 - val_loss: 1.3193 - val_acc: 0.5101
#
# Epoch 00035: val_loss did not improve from 1.24218
# Epoch 36/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.1979 - acc: 0.5405 - val_loss: 1.2378 - val_acc: 0.5441
#
# Epoch 00036: val_loss improved from 1.24218 to 1.23782, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 37/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.1662 - acc: 0.5500 - val_loss: 1.2614 - val_acc: 0.5156
#
# Epoch 00037: val_loss did not improve from 1.23782
# Epoch 38/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.1448 - acc: 0.5630 - val_loss: 1.2283 - val_acc: 0.5441
#
# Epoch 00038: val_loss improved from 1.23782 to 1.22830, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 39/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.1264 - acc: 0.5721 - val_loss: 1.2770 - val_acc: 0.5659
#
# Epoch 00039: val_loss did not improve from 1.22830
# Epoch 40/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.1043 - acc: 0.5802 - val_loss: 1.2760 - val_acc: 0.5367
#
# Epoch 00040: val_loss did not improve from 1.22830
# Epoch 41/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.0939 - acc: 0.5847 - val_loss: 1.2228 - val_acc: 0.5573
#
# Epoch 00041: val_loss improved from 1.22830 to 1.22282, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 42/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.0633 - acc: 0.5978 - val_loss: 1.2855 - val_acc: 0.5337
#
# Epoch 00042: val_loss did not improve from 1.22282
# Epoch 43/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.0515 - acc: 0.6065 - val_loss: 1.2683 - val_acc: 0.5520
#
# Epoch 00043: val_loss did not improve from 1.22282
# Epoch 44/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 1.0218 - acc: 0.6183 - val_loss: 1.3126 - val_acc: 0.5342
#
# Epoch 00044: val_loss did not improve from 1.22282
# Epoch 45/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.9937 - acc: 0.6276 - val_loss: 1.2085 - val_acc: 0.5639
#
# Epoch 00045: val_loss improved from 1.22282 to 1.20849, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# Epoch 46/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.9750 - acc: 0.6327 - val_loss: 1.2964 - val_acc: 0.5460
#
# Epoch 00046: val_loss did not improve from 1.20849
# Epoch 47/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.9576 - acc: 0.6426 - val_loss: 1.2553 - val_acc: 0.5717
#
# Epoch 00047: val_loss did not improve from 1.20849
# Epoch 48/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.9381 - acc: 0.6513 - val_loss: 1.2488 - val_acc: 0.5771
#
# Epoch 00048: val_loss did not improve from 1.20849
# Epoch 49/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.9094 - acc: 0.6606 - val_loss: 1.2530 - val_acc: 0.5898
#
# Epoch 00049: val_loss did not improve from 1.20849
# Epoch 50/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.8903 - acc: 0.6722 - val_loss: 1.2609 - val_acc: 0.5896
#
# Epoch 00050: val_loss did not improve from 1.20849
# Epoch 51/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.8670 - acc: 0.6781 - val_loss: 1.2426 - val_acc: 0.5927
#
# Epoch 00051: val_loss did not improve from 1.20849
# Epoch 52/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.8483 - acc: 0.6872 - val_loss: 1.3868 - val_acc: 0.5641
#
# Epoch 00052: val_loss did not improve from 1.20849
# Epoch 53/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.8182 - acc: 0.7034 - val_loss: 1.3009 - val_acc: 0.5957
#
# Epoch 00053: val_loss did not improve from 1.20849
# Epoch 54/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.8017 - acc: 0.7031 - val_loss: 1.3370 - val_acc: 0.6015
#
# Epoch 00054: val_loss did not improve from 1.20849
# Epoch 55/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.7742 - acc: 0.7178 - val_loss: 1.4250 - val_acc: 0.5887
#
# Epoch 00055: val_loss did not improve from 1.20849
# Epoch 56/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.7554 - acc: 0.7280 - val_loss: 1.4107 - val_acc: 0.5926
#
# Epoch 00056: val_loss did not improve from 1.20849
# Epoch 57/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.7473 - acc: 0.7335 - val_loss: 1.3946 - val_acc: 0.5960
#
# Epoch 00057: val_loss did not improve from 1.20849
# Epoch 58/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.7102 - acc: 0.7453 - val_loss: 1.6190 - val_acc: 0.5706
#
# Epoch 00058: val_loss did not improve from 1.20849
# Epoch 59/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.6955 - acc: 0.7504 - val_loss: 1.4868 - val_acc: 0.6070
#
# Epoch 00059: val_loss did not improve from 1.20849
# Epoch 60/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.6928 - acc: 0.7568 - val_loss: 1.5137 - val_acc: 0.6085
#
# Epoch 00060: val_loss did not improve from 1.20849
# Epoch 61/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.6564 - acc: 0.7676 - val_loss: 1.5097 - val_acc: 0.6084
#
# Epoch 00061: val_loss did not improve from 1.20849
# Epoch 62/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.6428 - acc: 0.7741 - val_loss: 1.4847 - val_acc: 0.5892
#
# Epoch 00062: val_loss did not improve from 1.20849
# Epoch 63/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.6367 - acc: 0.7771 - val_loss: 1.5485 - val_acc: 0.6017
#
# Epoch 00063: val_loss did not improve from 1.20849
# Epoch 64/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.6110 - acc: 0.7897 - val_loss: 1.5316 - val_acc: 0.6033
#
# Epoch 00064: val_loss did not improve from 1.20849
# Epoch 65/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.5824 - acc: 0.7954 - val_loss: 1.5640 - val_acc: 0.6141
#
# Epoch 00065: val_loss did not improve from 1.20849
# Epoch 66/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.5806 - acc: 0.8007 - val_loss: 1.6033 - val_acc: 0.6172
#
# Epoch 00066: val_loss did not improve from 1.20849
# Epoch 67/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.5504 - acc: 0.8105 - val_loss: 1.6474 - val_acc: 0.6110
#
# Epoch 00067: val_loss did not improve from 1.20849
# Epoch 68/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.5454 - acc: 0.8128 - val_loss: 1.5876 - val_acc: 0.6152
#
# Epoch 00068: val_loss did not improve from 1.20849
# Epoch 69/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.5379 - acc: 0.8176 - val_loss: 1.6552 - val_acc: 0.6110
#
# Epoch 00069: val_loss did not improve from 1.20849
# Epoch 70/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.5178 - acc: 0.8251 - val_loss: 1.7110 - val_acc: 0.6130
#
# Epoch 00070: val_loss did not improve from 1.20849
# Epoch 71/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.4918 - acc: 0.8325 - val_loss: 1.7871 - val_acc: 0.6150
#
# Epoch 00071: val_loss did not improve from 1.20849
# Epoch 72/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.4943 - acc: 0.8344 - val_loss: 1.7646 - val_acc: 0.6127
#
# Epoch 00072: val_loss did not improve from 1.20849
# Epoch 73/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.4767 - acc: 0.8398 - val_loss: 1.7790 - val_acc: 0.6149
#
# Epoch 00073: val_loss did not improve from 1.20849
# Epoch 74/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.4595 - acc: 0.8454 - val_loss: 1.7187 - val_acc: 0.6060
#
# Epoch 00074: val_loss did not improve from 1.20849
# Epoch 75/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.4466 - acc: 0.8502 - val_loss: 1.7624 - val_acc: 0.6173
#
# Epoch 00075: val_loss did not improve from 1.20849
# Epoch 76/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.4460 - acc: 0.8529 - val_loss: 1.8302 - val_acc: 0.6099
#
# Epoch 00076: val_loss did not improve from 1.20849
# Epoch 77/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.4261 - acc: 0.8606 - val_loss: 1.8737 - val_acc: 0.6128
#
# Epoch 00077: val_loss did not improve from 1.20849
# Epoch 78/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.4196 - acc: 0.8599 - val_loss: 1.8421 - val_acc: 0.6118
#
# Epoch 00078: val_loss did not improve from 1.20849
# Epoch 79/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3994 - acc: 0.8693 - val_loss: 1.8646 - val_acc: 0.6176
#
# Epoch 00079: val_loss did not improve from 1.20849
# Epoch 80/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3990 - acc: 0.8697 - val_loss: 1.8932 - val_acc: 0.6115
#
# Epoch 00080: val_loss did not improve from 1.20849
# Epoch 81/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3918 - acc: 0.8714 - val_loss: 1.8864 - val_acc: 0.6124
#
# Epoch 00081: val_loss did not improve from 1.20849
# Epoch 82/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3766 - acc: 0.8770 - val_loss: 1.9256 - val_acc: 0.6167
#
# Epoch 00082: val_loss did not improve from 1.20849
# Epoch 83/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3681 - acc: 0.8802 - val_loss: 1.9582 - val_acc: 0.6135
#
# Epoch 00083: val_loss did not improve from 1.20849
# Epoch 84/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3624 - acc: 0.8821 - val_loss: 2.0119 - val_acc: 0.6180
#
# Epoch 00084: val_loss did not improve from 1.20849
# Epoch 85/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3553 - acc: 0.8852 - val_loss: 1.9599 - val_acc: 0.6159
#
# Epoch 00085: val_loss did not improve from 1.20849
# Epoch 86/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3430 - acc: 0.8886 - val_loss: 1.9488 - val_acc: 0.6180
#
# Epoch 00086: val_loss did not improve from 1.20849
# Epoch 87/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3420 - acc: 0.8899 - val_loss: 2.0416 - val_acc: 0.6214
#
# Epoch 00087: val_loss did not improve from 1.20849
# Epoch 88/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3354 - acc: 0.8922 - val_loss: 2.0584 - val_acc: 0.6172
#
# Epoch 00088: val_loss did not improve from 1.20849
# Epoch 89/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3253 - acc: 0.8978 - val_loss: 2.0204 - val_acc: 0.6152
#
# Epoch 00089: val_loss did not improve from 1.20849
# Epoch 90/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3162 - acc: 0.8967 - val_loss: 2.0909 - val_acc: 0.6187
#
# Epoch 00090: val_loss did not improve from 1.20849
# Epoch 91/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3089 - acc: 0.9020 - val_loss: 2.0673 - val_acc: 0.6172
#
# Epoch 00091: val_loss did not improve from 1.20849
# Epoch 92/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3053 - acc: 0.9040 - val_loss: 2.0723 - val_acc: 0.6195
#
# Epoch 00092: val_loss did not improve from 1.20849
# Epoch 93/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.3029 - acc: 0.9027 - val_loss: 2.1455 - val_acc: 0.6127
#
# Epoch 00093: val_loss did not improve from 1.20849
# Epoch 94/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.2907 - acc: 0.9076 - val_loss: 2.1721 - val_acc: 0.6153
#
# Epoch 00094: val_loss did not improve from 1.20849
# Epoch 95/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.2860 - acc: 0.9088 - val_loss: 2.2292 - val_acc: 0.6223
#
# Epoch 00095: val_loss did not improve from 1.20849
# Epoch 96/100
# 25838/25838 [==============================] - 75s 3ms/step - loss: 0.2830 - acc: 0.9107 - val_loss: 2.1707 - val_acc: 0.6197
#
# Epoch 00096: val_loss did not improve from 1.20849
# Epoch 97/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.2814 - acc: 0.9123 - val_loss: 2.2171 - val_acc: 0.6209
#
# Epoch 00097: val_loss did not improve from 1.20849
# Epoch 98/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.2803 - acc: 0.9121 - val_loss: 2.1914 - val_acc: 0.6201
#
# Epoch 00098: val_loss did not improve from 1.20849
# Epoch 99/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.2708 - acc: 0.9167 - val_loss: 2.1985 - val_acc: 0.6195
#
# Epoch 00099: val_loss did not improve from 1.20849
# Epoch 100/100
# 25838/25838 [==============================] - 76s 3ms/step - loss: 0.2696 - acc: 0.9151 - val_loss: 2.2109 - val_acc: 0.6203
#
# Epoch 00100: val_loss did not improve from 1.20849

# %% [markdown]
# ## 6. Test the model.
#
# We trained the neural network and we achieved the highest validation accuracy of 62.23%. Now, we will use the test data to check how well our model generalizes.
#
# We score an astounding 60.2 % on the test set. Though we barely, made it to the first division, we still made it the 12th rank of the Kaggle competition.

# %%
predicted_test_labels = np.argmax(model.predict(test_data), axis=1)
test_labels = np.argmax(test_labels, axis=1)
print ("Accuracy score = ", accuracy_score(test_labels, predicted_test_labels))
# Out:
# Accuracy score =  0.6015603232098078

# %% [markdown]
# ## 7. Save the model.

# %%
from keras.models import model_from_json
model_json = model.to_json()
with open("/content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Models/model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("/content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Models/model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ## 8. Up next?
#
# Our neural network is trained and we are ready to use it in an application. In the accompanying IPython Notebook, we will notice an application which analyzes your webcam feed and identifies faces and then recognizes the emotions.
